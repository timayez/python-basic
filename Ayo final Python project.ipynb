# %%
# DEfining function
#Programme calculates the average grade of students
def average(Name, Anatomy, Physiology, Physics):
    solve = int(Anatomy+Physiology+Physics)/3
    print("{0}'s grade: Anatomy={1},Physiology={2}, Physics ={3}, and the average is {4}.".format(Name, Anatomy, Physiology, Physics, round(solve)))
print()
average("Helen", 45,50,87)
print()
average("paul", 60, 87,64)
print()
average("Ayomide", 70,80,67)
# Out:
# Helen's grade: Anatomy=45,Physiology=50, Physics =87, and the average is 61.
#
# paul's grade: Anatomy=60,Physiology=87, Physics =64, and the average is 70.
#
# Ayomide's grade: Anatomy=70,Physiology=80, Physics =67, and the average is 72.

# %%
 #(1)Using 'enumerate and list function' to sort a class grade 
class_grades = [95.83,97.83,86.96,91.30,91.30,95.65,71.74,95.65,91.30,73.91,91.67,95.83,95.83,91.67,91.67,80.00,64.0,88.00,92.00,80.00,60.00,92.00,96.00,100.00,92.00,88.00,96.00,100.00,96.00,100.00,92.00,88.00]
new_grades = sorted(class_grades, reverse=True)
# use the 'sort()' to arrange in decesing order using the 'reverse' argument 
for each, grade in enumerate(new_grades, start=1): # index starts at 0 by default, we fix this by using 'start argument' explisitly stating what number we want the index from
    print(each, grade)

# %%
# (2)booleon logic code
print("What should you do today?")
print("Hunn..., let's find out")
temp= int(input("what is your weather like?"))
if temp >15<20: 
    print("looks like a warm day")
    print("Do something outdoors, go hikking?")
elif temp<=14:
    print("it is a cold day")
    print("take your jacket with you")
elif temp > 46: 
    print("it is a very hot day")
    print("you should stay indoor")
    print("Unless you are going foe swimming")
else:
    print("No value inputted")
print("Have a lovely day!!")

# %%
#another while loop example from datacamp
# Initialize offset
offset = -5
# Code the while loop (starts here)
while offset != 0 :
    print("correcting...")
    if offset > 0:
      offset = offset-1
    else :
      offset = offset +1  
    print(offset)

# %%
#Data structure
class_grades = {"Helen":95.83,
                "bill":97.83,
                "weit":86.96,
                "all":91.30,
                "rick":1.67
                }
class_grades['Helen']= 67.5 #Helen's new grade 
Helen_grade= class_grades["Helen"]
class_grade.["Hellen"]
print(class_grades)

# %%
# (4)Object-oriented programming (OOP) 
class Dog:
    age = int(input("how old is your dog"))
    breed = input("Enter your dogs breed")
    name= input("Enter your dogs name")
    def describe(self): 
        return f"{self.name} is a {self.age} year-old, {self.breed} Dog"
name= Dog()
print(name.describe())
appointment_time= input("What time do you want?")
print(f"Appointment time set for {appointment_time}")
# Out:
# how old is your dog 2
# Enter your dogs breed rot
# Enter your dogs name will
# will is a 2 year-old, rot Dog
# What time do you want? 2pm
# Appointment time set for 2pm

# %%
class Person:
    age = int(input("how old is your dog")) 
    breed = input("Enter your dogs breed")
    name= input("Enter your dogs name")
    def describe(self): 
        return f"{self.name} is a {self.age} year-old, {self.breed} Dog"
name= Person()
print(name.describe())

#value error because code specifiys the type of input as int, user entered a str
# Out:
# how old is your dog will
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 class Person:
#       2     age = int(input("how old is your dog"))
#       3     breed = input("Enter your dogs breed")
#
# Input In [4], in Person()
#       1 class Person:
# ----> 2     age = int(input("how old is your dog"))
#       3     breed = input("Enter your dogs breed")
#       4     name= input("Enter your dogs name")
#
# ValueError: invalid literal for int() with base 10: 'will'

# %%
# (5) Handling error message
total= 2+ "boys"
print(total)

# type error is returned becuse two diffrent data types cant be added together. 
#we can handle this error by defining boys then add them. look below
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 # (5) Handling error message
# ----> 2 total= 2+ "boys"
#       3 print(total)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Exception handling
try:
  print(x)
except NameError:
  print("Define variable x")
except:
  print("Something else went wrong")
# Out:
# Define variable x
